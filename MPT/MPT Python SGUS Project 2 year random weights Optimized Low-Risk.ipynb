# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## **Data Processing**

# %%
#Import portfolio equity data from spreadsheet in Google Drive
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQT9ZvlCv6SgOafgV_VyOVrqbn0F5O--Ihh1ZR7Gjd4quqsGAeJEGIXhdaFSGfngl4eKKPRqIDm5hpj/pub?gid=1861521421&single=true&output=csv') #last 2 year
df.head()
# Out:
#          Date  Pre-Holiday Effect  ...    Momentum  Reddit Sentiment
# 0  1546318800          97070.4781  ...  93075.7998          100000.0
# 1  1546441200          97070.4781  ...  93075.7998          100000.0
# 2  1546491600          98662.8771  ...  91830.8861          100000.0
# 3  1546578000          97933.3140  ...  92461.6424          100000.0
# 4  1546664400          97933.3140  ...  92498.4837          100000.0
#
# [5 rows x 6 columns]

# %%
#converting unix timestamp into regular date format
df['Date']= pd.to_datetime(df['Date'], unit='s').dt.date
df.head()
# Out:
#          Date  Pre-Holiday Effect  ...    Momentum  Reddit Sentiment
# 0  2019-01-01          97070.4781  ...  93075.7998          100000.0
# 1  2019-01-02          97070.4781  ...  93075.7998          100000.0
# 2  2019-01-03          98662.8771  ...  91830.8861          100000.0
# 3  2019-01-04          97933.3140  ...  92461.6424          100000.0
# 4  2019-01-05          97933.3140  ...  92498.4837          100000.0
#
# [5 rows x 6 columns]

# %%
#setting index to 'Date' column
df = df.set_index(pd.to_datetime(df['Date']))
df = df.drop('Date', axis=1)
df.head()
# Out:
#             Pre-Holiday Effect  ...  Reddit Sentiment
# Date                            ...
# 2019-01-01          97070.4781  ...          100000.0
# 2019-01-02          97070.4781  ...          100000.0
# 2019-01-03          98662.8771  ...          100000.0
# 2019-01-04          97933.3140  ...          100000.0
# 2019-01-05          97933.3140  ...          100000.0
#
# [5 rows x 5 columns]

# %% [markdown]
# ## **Co-variance Matrix of assets/strategies**

# %%
#Co-variance matrix
# Log of percentage change
cov_matrix = df.pct_change().apply(lambda x: np.log(1+x)).cov()

# %%
plt.figure(figsize=(12,7))
cov_matrix_plot = sns.heatmap(cov_matrix, annot=True)

# %% [markdown]
# ## **Correlation Matrix of Assets/Strategies**

# %%
#Correlation matrix
corr_matrix = df.pct_change().apply(lambda x: np.log(1+x)).corr()

# %%
plt.figure(figsize=(12,7))
corr_matrix_plot = sns.heatmap(corr_matrix, vmin=-1, vmax=1, annot=True)

# %% [markdown]
# ## **Annual Returns**

# %%
# Yearly returns for individual assets/strategies
ind_er = df.resample('Y').last().pct_change().mean() #for more than 1 year
ind_er
# Out:
# Pre-Holiday Effect        0.120012
# Carry Trade with Forex    0.085539
# Risk Premia               0.073794
# Momentum                  0.147510
# Reddit Sentiment          0.185401
# dtype: float64

# %% [markdown]
# ## **Volatility (Standard Deviation)**

# %%
# Converting daily standard deviation to annual standard deviation
# Volatility is given by the annual standard deviation. We multiply by 250 because there are 250 trading days/year.
ann_sd = df.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250))
ann_sd
# Out:
# Pre-Holiday Effect        0.036998
# Carry Trade with Forex    0.050871
# Risk Premia               0.058815
# Momentum                  0.058204
# Reddit Sentiment          0.125153
# dtype: float64

# %% [markdown]
# ## **Comparison of Returns & Volatility of Assets/Strategies**

# %%
# Creating a table for visualising returns and volatility of assets/strategies
assets = pd.concat([ind_er, ann_sd], axis=1) 
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#                          Returns  Volatility
# Pre-Holiday Effect      0.120012    0.036998
# Carry Trade with Forex  0.085539    0.050871
# Risk Premia             0.073794    0.058815
# Momentum                0.147510    0.058204
# Reddit Sentiment        0.185401    0.125153

# %% [markdown]
# ## **Plotting Efficient Frontier**

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset/strategy weights

num_assets = len(df.columns)
num_portfolios = 100000 #number of portfolios to plot

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its weights 
    p_ret.append(returns)
    
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio Variance
    sd = np.sqrt(var) # Daily standard deviation
    ann_sd = sd*np.sqrt(250) # Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}

for counter, symbol in enumerate(df.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]

# %%
portfolios  = pd.DataFrame(data)
portfolios.head() # Dataframe of the number of portfolios(num_portfolios) created
# Out:
#     Returns  Volatility  ...  Momentum weight  Reddit Sentiment weight
# 0  0.109853    0.025326  ...         0.148179                 0.032387
# 1  0.112595    0.026948  ...         0.118451                 0.106519
# 2  0.156066    0.063335  ...         0.228009                 0.480152
# 3  0.127498    0.041764  ...         0.145431                 0.288875
# 4  0.137836    0.039866  ...         0.277424                 0.258241
#
# [5 rows x 7 columns]

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[12,12])
plt.xlabel('Volatility')
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %% [markdown]
# ## **Getting Weights for Lowest Volatility**

# %%
#Getting parameter/weights of the point with minimum volatility
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.                               
min_vol_port
# Out:
# Returns                          0.110128
# Volatility                       0.024477
# Pre-Holiday Effect weight        0.432352
# Carry Trade with Forex weight    0.188773
# Risk Premia  weight              0.200497
# Momentum weight                  0.152394
# Reddit Sentiment weight          0.025983
# Name: 21686, dtype: float64

# %%
assets
# Out:
#                          Returns  Volatility
# Pre-Holiday Effect      0.120012    0.036998
# Carry Trade with Forex  0.085539    0.050871
# Risk Premia             0.073794    0.058815
# Momentum                0.147510    0.058204
# Reddit Sentiment        0.185401    0.125153

# %%
#Sharpe Ratio of minimally volatile portfolio
sharpe_ratio_min_vol = min_vol_port[0] / min_vol_port[1]
sharpe_ratio_min_vol
# Out:
# 4.499233860371997

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[12,12])
plt.xlabel('Volatility')
plt.ylabel('Returns')
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)

# %% [markdown]
# ## **Getting Weights for Highest Sharpe Ratio**

# %%
# Finding the optimal portfolio (i.e. Highest Sharpe Ratio)

# risk factor(risk-free rate)
rf = 0.0161  #1.61% Average return of Singapore Savings Bonds over 10 years https://www.mas.gov.sg/bonds-and-bills/Singapore-Savings-Bonds

optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns                          0.118638
# Volatility                       0.025334
# Pre-Holiday Effect weight        0.461594
# Carry Trade with Forex weight    0.133388
# Risk Premia  weight              0.136129
# Momentum weight                  0.212895
# Reddit Sentiment weight          0.055994
# Name: 40709, dtype: float64

# %%
assets
# Out:
#                          Returns  Volatility
# Pre-Holiday Effect      0.120012    0.036998
# Carry Trade with Forex  0.085539    0.050871
# Risk Premia             0.073794    0.058815
# Momentum                0.147510    0.058204
# Reddit Sentiment        0.185401    0.125153

# %%
#Sharpe Ratio of Optimally risky portfolio
sharpe_ratio_risky = optimal_risky_port[0] / optimal_risky_port[1]
sharpe_ratio_risky
# Out:
# 4.6829068345005

# %%
# Plotting optimal portfolio (Blue Star)
plt.subplots(figsize=(12, 12))
plt.xlabel('Volatility')
plt.ylabel('Returns')
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='b', marker='*', s=500)

# %%
from google.colab import drive
drive.mount('/drive')
portfolios.to_excel('/drive/My Drive/SGUS Fintech Algo-trading BI Project/Working Folders/Phase 2 Algo-Trading/MPT/MPT Python SGUS Project 2 year random weights Optimized Low-Risk.xlsx')
# Out:
# Mounted at /drive
