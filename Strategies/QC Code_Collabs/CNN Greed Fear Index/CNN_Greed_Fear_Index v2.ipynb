# %%
pip install fear-and-greed

# %%
import fear_and_greed

fear_and_greed.get()
# Out:
# FearGreedIndex(value=48, description='Neutral', last_update=datetime.datetime(2021, 6, 4, 17, 17, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>))
